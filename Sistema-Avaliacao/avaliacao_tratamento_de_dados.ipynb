# %%
import pandas as pd
from pathlib import Path

# Use paths relativos para evitar problemas com backslashes em strings
base = Path('.')

raw_path = base / 'raw_data.csv'
capabilities_path = base / 'avaliacao - questoes_capabilities.csv'

# Leitura dos dataframes
raw_df = pd.read_csv(raw_path)
cap_df = pd.read_csv(capabilities_path, encoding='utf-8')

# Mostrar as primeiras linhas de cada um
print('raw_data.csv head:')
display(raw_df.head())
print('\navaliação-questoes_capabilities.csv head:')
display(cap_df.head())
# Out:
# raw_data.csv head:
#      Avaliacao Aluno Questao                                Parte  \
# 0  Diagnostica  D000     Q01            Linguagens de Programação
# 1  Diagnostica  D000     Q02            Linguagens de Programação
# 2  Diagnostica  D000     Q03            Linguagens de Programação
# 3  Diagnostica  D000     Q04  Contato com Conceitos e Ferramentas
# 4  Diagnostica  D000     Q05  Contato com Conceitos e Ferramentas
#
#                                             Resposta  \
# 0  Seria um grande avanço, visto que a escola nao...
# 1  A situação "boa" varia do cenario, ja que cada...
# 2  Seria importante por seu facil aprendizado, po...
# 3                  Já programei em projetos pessoais
# 4                Já utilizei em atividades da escola
#
#                                      comentarios_LLM  score  \
# 0  A resposta reconhece o uso de Java em sistemas...      1
# 1  A resposta é genérica e não descreve situações...      1
# 2  Reconhece a importância do JavaScript no naveg...      1
# 3  Indica experiência prática direta com programa...      3
# 4  Demonstra contato prévio com banco de dados, m...      2
#
#        problema_principal
# 0    resposta_superficial
# 1    resposta_superficial
# 2    resposta_superficial
# 3  sem_problema_relevante
# 4    resposta_superficial
# avaliação-questoes_capabilities.csv head:
#   questao capability
# 0      Q1       POO5
# 1      Q1       POO7
# 2      Q2       POO1
# 3      Q2       POO7
# 4      Q3       POO6
